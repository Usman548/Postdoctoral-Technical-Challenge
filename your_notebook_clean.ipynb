# %% [markdown]
# <a href="https://colab.research.google.com/github/Usman548/Postdoctoral-Technical-Challenge/blob/main/your_notebook_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Complete Google Colab Notebook for All Three Tasks

# %%
# !pip -q install -U transformers accelerate huggingface_hub safetensors

# %%
# @title 📦 Step 1: Clone Repository and Setup

import os
import sys
from pathlib import Path

print("="*60)
print("PNEUMONIA MULTI-MODAL AI SYSTEM")
print("="*60)

# Clone your GitHub repository
# Replace with your actual GitHub URL
repo_url = "https://github.com/Usman548/Postdoctoral-Technical-Challenge.git"

print(f"\n📂 Cloning repository: {repo_url}")
# !git clone {repo_url}

# Get repository name from URL
repo_name = repo_url.split('/')[-1].replace('.git', '')
# %cd {repo_name}

print(f"\n✅ Current directory: {os.getcwd()}")
# !ls -la
# Out:
# ============================================================
# PNEUMONIA MULTI-MODAL AI SYSTEM
# ============================================================
#
# 📂 Cloning repository: https://github.com/Usman548/Postdoctoral-Technical-Challenge.git
# Cloning into 'Postdoctoral-Technical-Challenge'...
# remote: Enumerating objects: 196, done.
# remote: Counting objects: 100% (196/196), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 196 (delta 43), reused 180 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (196/196), 11.60 MiB | 17.01 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# /content/Postdoctoral-Technical-Challenge
#
# ✅ Current directory: /content/Postdoctoral-Technical-Challenge
# total 68
# drwxr-xr-x 12 root root 4096 Feb 19 13:58 .
# drwxr-xr-x  1 root root 4096 Feb 19 13:58 ..
# drwxr-xr-x  3 root root 4096 Feb 19 13:58 core
# drwxr-xr-x  3 root root 4096 Feb 19 13:58 data
# drwxr-xr-x  8 root root 4096 Feb 19 13:58 .git
# -rw-r--r--  1 root root   66 Feb 19 13:58 .gitattributes
# drwxr-xr-x  5 root root 4096 Feb 19 13:58 models
# drwxr-xr-x  2 root root 4096 Feb 19 13:58 notebooks
# -rw-r--r--  1 root root 8800 Feb 19 13:58 README.md
# drwxr-xr-x  4 root root 4096 Feb 19 13:58 reports
# -rw-r--r--  1 root root  117 Feb 19 13:58 requirements.txt
# drwxr-xr-x  4 root root 4096 Feb 19 13:58 task1_classification
# drwxr-xr-x  3 root root 4096 Feb 19 13:58 task2_report_generation
# drwxr-xr-x  5 root root 4096 Feb 19 13:58 task3_retrieval
# drwxr-xr-x  3 root root 4096 Feb 19 13:58 utils

# %%
# @title 📦 Step 2: Install Dependencies

print("="*60)
print("INSTALLING DEPENDENCIES")
print("="*60)

# Install from requirements.txt
# !pip install -q -r requirements.txt

# Install additional packages for token handling
# !pip install -q python-dotenv huggingface-hub

# Verify installations
import torch
import transformers
import faiss
import medmnist

print(f"\n✅ PyTorch version: {torch.__version__}")
print(f"✅ Transformers version: {transformers.__version__}")
print(f"✅ FAISS version: {faiss.__version__}")
print(f"✅ MedMNIST version: {medmnist.__version__}")
print(f"✅ CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    # !nvidia-smi --query-gpu=memory.total --format=csv,noheader,nounits
# Out:
# ============================================================
# INSTALLING DEPENDENCIES
# ============================================================
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 52.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 11.5 MB/s eta 0:00:00
#
# ✅ PyTorch version: 2.9.0+cu128
# ✅ Transformers version: 5.0.0
# ✅ FAISS version: 1.13.2
# ✅ MedMNIST version: 3.0.2
# ✅ CUDA Available: True
# ✅ GPU: Tesla T4
# 15360

# %%
# @title 🔑 Step 3: HuggingFace Token Setup (Required for Task 2)

import os
from getpass import getpass
from pathlib import Path
import sys
from google.colab import userdata

print("="*60)
print("🔑 HUGGINGFACE TOKEN SETUP")
print("="*60)
print("\nTo use MedGemma for Task 2, you need a HuggingFace token.")
print("Get your token at: https://huggingface.co/settings/tokens")
print("Request access to: https://huggingface.co/google/medgemma-4b-it")

# Try multiple methods to get token
HF_TOKEN = None


# Method 1: Check if already in environment
HF_TOKEN = userdata.get('HF_TOKEN')
if HF_TOKEN:
    print("✅ Found token in environment variables")

# Method 2: Check for .env file
if not HF_TOKEN:
    env_path = Path('.env')
    if env_path.exists():
        with open(env_path, 'r') as f:
            for line in f:
                if line.startswith('HF_TOKEN='):
                    HF_TOKEN = line.strip().split('=')[1]
                    print("✅ Found token in .env file")
                    break

# Method 3: Check Google Colab Secrets
if not HF_TOKEN:
    try:
        from google.colab import userdata
        HF_TOKEN = userdata.get('HF_TOKEN')
        print("✅ Found token in Colab Secrets")
    except:
        pass

# Method 4: Ask user to input
if not HF_TOKEN:
    print("\n📝 Please enter your HuggingFace token")
    HF_TOKEN = getpass("Token: ")

    # Option to save for next time
    save = input("\nSave token to .env file for future sessions? (y/n): ").lower()
    if save == 'y':
        with open('.env', 'w') as f:
            f.write(f'HF_TOKEN={HF_TOKEN}')
        print("✅ Token saved to .env file")
        print("⚠️  Make sure .env is in your .gitignore!")

# Set environment variable
os.environ['HF_TOKEN'] = HF_TOKEN
print(f"\n✅ Token set: {HF_TOKEN[:5]}...{HF_TOKEN[-5:]}")

# Verify token works
print("\n🔄 Verifying token...")
from huggingface_hub import whoami
try:
    user = whoami(token=HF_TOKEN)
    print(f"✅ Successfully logged in as: {user['name']}")
    print("✅ Token is valid and ready for Task 2!")
except Exception as e:
    print(f"❌ Token validation failed: {e}")
    print("Please check your token and try again.")

# Create a helper function for Task 2
def get_hf_token():
    """Helper function to get HF token for Task 2 notebooks"""
    return os.environ.get('HF_TOKEN')

print("\n✅ Token setup complete! You can now run Task 2.")
# Out:
# ============================================================
# 🔑 HUGGINGFACE TOKEN SETUP
# ============================================================
#
# To use MedGemma for Task 2, you need a HuggingFace token.
# Get your token at: https://huggingface.co/settings/tokens
# Request access to: https://huggingface.co/google/medgemma-4b-it
# ✅ Found token in environment variables
#
# ✅ Token set: hf_En...PYuyH
#
# 🔄 Verifying token...
# ✅ Successfully logged in as: usman548
# ✅ Token is valid and ready for Task 2!
#
# ✅ Token setup complete! You can now run Task 2.

# %%
# @title 💾 Step 4: Mount Google Drive to Save Results (Optional)

from google.colab import drive
drive.mount('/content/drive')

# Create folders in Drive
# !mkdir -p /content/drive/MyDrive/pneumonia_ai/models
# !mkdir -p /content/drive/MyDrive/pneumonia_ai/reports

print("\n✅ Google Drive mounted")
print("📁 Models will be saved to: /content/drive/MyDrive/pneumonia_ai/models")
print("📁 Reports will be saved to: /content/drive/MyDrive/pneumonia_ai/reports")

# Create symlinks (optional)
# !ln -sf /content/drive/MyDrive/pneumonia_ai/models ./models/drive_models
# !ln -sf /content/drive/MyDrive/pneumonia_ai/reports ./reports/drive_reports
# Out:
# Mounted at /content/drive
#
# ✅ Google Drive mounted
# 📁 Models will be saved to: /content/drive/MyDrive/pneumonia_ai/models
# 📁 Reports will be saved to: /content/drive/MyDrive/pneumonia_ai/reports

# %%
# @title 🔍 Step 5: Test Token with MedGemma (Optional)

import os

print("="*60)
print("TESTING HUGGINGFACE TOKEN WITH MEDGEMMA")
print("="*60)

HF_TOKEN = userdata.get('HF_TOKEN')

if not HF_TOKEN:
    print("❌ No token found! Please run Step 3 first.")
else:
    print(f"✅ Token found: {HF_TOKEN[:5]}...{HF_TOKEN[-5:]}")

    # Test loading a small part of the model
    print("\n🔄 Testing token with MedGemma...")
    from transformers import AutoConfig

    try:
        # Just test config loading (doesn't download full model)
        config = AutoConfig.from_pretrained(
            "google/medgemma-4b-it",
            token=HF_TOKEN,
            trust_remote_code=True
        )
        print("✅ Token works! You can now run Task 2.")
        print("📝 Model architecture:", config.architectures[0] if config.architectures else "Unknown")
    except Exception as e:
        print(f"❌ Token test failed: {e}")
        print("Please check:")
        print("1. Token is correct")
        print("2. You have requested access at: https://huggingface.co/google/medgemma-4b-it")
        print("3. Your account has been granted access")
# Out:
# ============================================================
# TESTING HUGGINGFACE TOKEN WITH MEDGEMMA
# ============================================================
# ✅ Token found: hf_En...PYuyH
#
# 🔄 Testing token with MedGemma...
# config.json:   0%|          | 0.00/2.47k [00:00<?, ?B/s]
# ✅ Token works! You can now run Task 2.
# 📝 Model architecture: Gemma3ForConditionalGeneration

# %%
# @title 📊 Step 6: Run Task 1 - CNN Classification

print("="*60)
print("TASK 1: CNN CLASSIFICATION")
print("="*60)


print("\n🔄 Option B: Running training directly")
# %cd task1_classification

# Train with custom parameters
model_name = "resnet18"  # 'custom', 'resnet18', 'efficientnet-b0', 'vit-tiny'
batch_size = 32
epochs = 1  # Increase for better results

# !python train.py --model {model_name} --batch_size {batch_size} --epochs {epochs}

# Evaluate
# !python evaluate.py --model_path models/saved/best_model_{model_name}.pth --model_name {model_name}

# %cd ..

print("\n✅ Task 1 completed!")
# Out:
# ============================================================
# TASK 1: CNN CLASSIFICATION
# ============================================================
#
# 🔄 Option B: Running training directly
# /content/Postdoctoral-Technical-Challenge/task1_classification
# 2026-02-19 14:01:01 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:01:01 - __main__ - INFO - PNEUMONIA CLASSIFICATION TRAINING
# INFO:__main__:PNEUMONIA CLASSIFICATION TRAINING
# 2026-02-19 14:01:01 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:01:01 - __main__ - INFO - PyTorch version: 2.9.0+cu128
# INFO:__main__:PyTorch version: 2.9.0+cu128
# 2026-02-19 14:01:01 - __main__ - INFO - CPU cores available: 1
# INFO:__main__:CPU cores available: 1
# 2026-02-19 14:01:01 - __main__ - INFO - Using device: CPU (as specified)
# INFO:__main__:Using device: CPU (as specified)
# 2026-02-19 14:01:01 - __main__ - INFO - Set number of CPU threads to 1
# INFO:__main__:Set number of CPU threads to 1
# 2026-02-19 14:01:01 - __main__ - INFO - Initializing CPU Trainer with config: TrainingConfig(model_name='resnet18', num_classes=2, batch_size=32, learning_rate=0.001, num_epochs=1, patience=10, weight_decay=0.0001, augment=True, random_seed=42, device='cpu', num_workers=0, pin_memory=False, verbose=True, output_dir='reports/task1', models_dir='models/saved')
# INFO:__main__:Initializing CPU Trainer with config: TrainingConfig(model_name='resnet18', num_classes=2, batch_size=32, learning_rate=0.001, num_epochs=1, patience=10, weight_decay=0.0001, augment=True, random_seed=42, device='cpu', num_workers=0, pin_memory=False, verbose=True, output_dir='reports/task1', models_dir='models/saved')
# 2026-02-19 14:01:01 - __main__ - INFO - Loading PneumoniaMNIST dataset...
# INFO:__main__:Loading PneumoniaMNIST dataset...
# 100% 4.17M/4.17M [00:01<00:00, 3.37MB/s]
# INFO:data.data_loader:Training set size: 4708
# INFO:data.data_loader:Validation set size: 524
# INFO:data.data_loader:Test set size: 624
# 2026-02-19 14:01:03 - __main__ - INFO - Dataset loaded successfully:
# INFO:__main__:Dataset loaded successfully:
# 2026-02-19 14:01:03 - __main__ - INFO -   - Training samples: 4708
# INFO:__main__:  - Training samples: 4708
# 2026-02-19 14:01:03 - __main__ - INFO -   - Validation samples: 524
# INFO:__main__:  - Validation samples: 524
# 2026-02-19 14:01:03 - __main__ - INFO -   - Test samples: 624
# INFO:__main__:  - Test samples: 624
# 2026-02-19 14:01:03 - __main__ - INFO -   - Class names: ['Normal', 'Pneumonia']
# INFO:__main__:  - Class names: ['Normal', 'Pneumonia']
# 2026-02-19 14:01:03 - __main__ - INFO -   - Class weights: [tensor(0.0008), tensor(0.0003)]
# INFO:__main__:  - Class weights: [tensor(0.0008), tensor(0.0003)]
# 2026-02-19 14:01:03 - __main__ - INFO - Creating resnet18 model...
# INFO:__main__:Creating resnet18 model...
# 2026-02-19 14:01:03 - __main__ - INFO - Model created successfully:
# INFO:__main__:Model created successfully:
# 2026-02-19 14:01:03 - __main__ - INFO -   - Total parameters: 11,168,706
# INFO:__main__:  - Total parameters: 11,168,706
# 2026-02-19 14:01:03 - __main__ - INFO -   - Trainable parameters: 11,168,706
# INFO:__main__:  - Trainable parameters: 11,168,706
# 2026-02-19 14:01:03 - __main__ - INFO -   - Device: cpu
# INFO:__main__:  - Device: cpu
# 2026-02-19 14:01:03 - __main__ - INFO - Using weighted CrossEntropyLoss with weights: tensor([0.0008, 0.0003])
# INFO:__main__:Using weighted CrossEntropyLoss with weights: tensor([0.0008, 0.0003])
# 2026-02-19 14:01:03 - __main__ - INFO - Optimizer: Adam (lr=0.001, weight_decay=0.0001)
# INFO:__main__:Optimizer: Adam (lr=0.001, weight_decay=0.0001)
# 2026-02-19 14:01:03 - __main__ - INFO - Scheduler: ReduceLROnPlateau (factor=0.5, patience=5)
# INFO:__main__:Scheduler: ReduceLROnPlateau (factor=0.5, patience=5)
# 2026-02-19 14:01:03 - __main__ - INFO - Trainer initialization complete
# INFO:__main__:Trainer initialization complete
# 2026-02-19 14:01:03 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:01:03 - __main__ - INFO - Starting training on cpu
# INFO:__main__:Starting training on cpu
# 2026-02-19 14:01:03 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# Epoch 1/1 [Train]: 100% 148/148 [02:51<00:00,  1.16s/it, loss=0.8816, acc=89.17%, lr=0.001000]
# Epoch 1/1 [Val]: 100% 17/17 [00:05<00:00,  2.89it/s, loss=0.6341, acc=79.58%]
# 2026-02-19 14:04:01 - __main__ - INFO -
# Epoch 1/1 Summary:
# INFO:__main__:
# Epoch 1/1 Summary:
# 2026-02-19 14:04:01 - __main__ - INFO -   Train Loss: 0.3061 | Train Acc: 89.17%
# INFO:__main__:  Train Loss: 0.3061 | Train Acc: 89.17%
# 2026-02-19 14:04:01 - __main__ - INFO -   Val Loss: 0.3554 | Val Acc: 79.58%
# INFO:__main__:  Val Loss: 0.3554 | Val Acc: 79.58%
# 2026-02-19 14:04:01 - __main__ - INFO -   Learning Rate: 0.001000
# INFO:__main__:  Learning Rate: 0.001000
# 2026-02-19 14:04:01 - __main__ - INFO -   Time: 177.36s
# INFO:__main__:  Time: 177.36s
# 2026-02-19 14:04:01 - __main__ - INFO -   ✓ New best model! Val Acc: 79.58%
# INFO:__main__:  ✓ New best model! Val Acc: 79.58%
# 2026-02-19 14:04:01 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:04:01 - __main__ - INFO - Training completed in 177.49s (2.96 minutes)
# INFO:__main__:Training completed in 177.49s (2.96 minutes)
# 2026-02-19 14:04:01 - __main__ - INFO - Best validation accuracy: 79.58%
# INFO:__main__:Best validation accuracy: 79.58%
# 2026-02-19 14:04:01 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:04:01 - __main__ - INFO - Generating training visualizations...
# INFO:__main__:Generating training visualizations...
# 2026-02-19 14:04:02 - __main__ - INFO - Visualizations saved to reports/task1/figures
# INFO:__main__:Visualizations saved to reports/task1/figures
# 2026-02-19 14:04:02 - __main__ - INFO - Training history saved to reports/task1/training_history.json
# INFO:__main__:Training history saved to reports/task1/training_history.json
# 2026-02-19 14:04:02 - __main__ - INFO -
# ============================================================
# INFO:__main__:
# ============================================================
# 2026-02-19 14:04:02 - __main__ - INFO - TRAINING COMPLETED SUCCESSFULLY
# INFO:__main__:TRAINING COMPLETED SUCCESSFULLY
# 2026-02-19 14:04:02 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:04:09 - __main__ - INFO - Using device: cpu
# INFO:__main__:Using device: cpu
# 2026-02-19 14:04:09 - __main__ - INFO - Loading test dataset...
# INFO:__main__:Loading test dataset...
# INFO:data.data_loader:Training set size: 4708
# INFO:data.data_loader:Validation set size: 524
# INFO:data.data_loader:Test set size: 624
# 2026-02-19 14:04:09 - __main__ - INFO - Test dataset loaded:
# INFO:__main__:Test dataset loaded:
# 2026-02-19 14:04:09 - __main__ - INFO -   - Test samples: 624
# INFO:__main__:  - Test samples: 624
# 2026-02-19 14:04:09 - __main__ - INFO -   - Class names: ['Normal', 'Pneumonia']
# INFO:__main__:  - Class names: ['Normal', 'Pneumonia']
# 2026-02-19 14:04:09 - __main__ - INFO -   - Batch size: 64
# INFO:__main__:  - Batch size: 64
# 2026-02-19 14:04:09 - __main__ - INFO - Loading model from models/saved/best_model_resnet18.pth
# INFO:__main__:Loading model from models/saved/best_model_resnet18.pth
# 2026-02-19 14:04:10 - __main__ - INFO - Loaded checkpoint from epoch 0 with val_acc: 79.58015267175573
# INFO:__main__:Loaded checkpoint from epoch 0 with val_acc: 79.58015267175573
# 2026-02-19 14:04:10 - __main__ - INFO - Model loaded successfully:
# INFO:__main__:Model loaded successfully:
# 2026-02-19 14:04:10 - __main__ - INFO -   - Architecture: resnet18
# INFO:__main__:  - Architecture: resnet18
# 2026-02-19 14:04:10 - __main__ - INFO -   - Total parameters: 11,168,706
# INFO:__main__:  - Total parameters: 11,168,706
# 2026-02-19 14:04:10 - __main__ - INFO - Evaluator initialization complete
# INFO:__main__:Evaluator initialization complete
# 2026-02-19 14:04:10 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:04:10 - __main__ - INFO - STARTING MODEL EVALUATION
# INFO:__main__:STARTING MODEL EVALUATION
# 2026-02-19 14:04:10 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:04:10 - __main__ - INFO - Running inference on test set...
# INFO:__main__:Running inference on test set...
# Evaluating: 100% 10/10 [00:06<00:00,  1.56it/s]
# 2026-02-19 14:04:16 - __main__ - INFO - Inference completed. Processed 624 samples.
# INFO:__main__:Inference completed. Processed 624 samples.
# 2026-02-19 14:04:16 - __main__ - INFO - Calculating evaluation metrics...
# INFO:__main__:Calculating evaluation metrics...
# 2026-02-19 14:04:16 - __main__ - INFO - Generating visualizations...
# INFO:__main__:Generating visualizations...
# 2026-02-19 14:04:18 - __main__ - INFO - Visualizations saved to reports/task1/figures
# INFO:__main__:Visualizations saved to reports/task1/figures
# 2026-02-19 14:04:18 - __main__ - INFO - Analyzing failure cases...
# INFO:__main__:Analyzing failure cases...
# 2026-02-19 14:04:18 - __main__ - INFO - Found 111 misclassified samples (12 FP, 99 FN)
# INFO:__main__:Found 111 misclassified samples (12 FP, 99 FN)
# 2026-02-19 14:04:18 - __main__ - INFO - Results saved to reports/task1
# INFO:__main__:Results saved to reports/task1
# 2026-02-19 14:04:18 - __main__ - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2026-02-19 14:04:18 - __main__ - INFO - EVALUATION SUMMARY
# INFO:__main__:EVALUATION SUMMARY
# 2026-02-19 14:04:18 - __main__ - INFO - ==================================================
# INFO:__main__:==================================================
# 2026-02-19 14:04:18 - __main__ - INFO - Test Samples: 624
# INFO:__main__:Test Samples: 624
# 2026-02-19 14:04:18 - __main__ - INFO - Accuracy: 0.8221
# INFO:__main__:Accuracy: 0.8221
# 2026-02-19 14:04:18 - __main__ - INFO - Precision: 0.9604
# INFO:__main__:Precision: 0.9604
# 2026-02-19 14:04:18 - __main__ - INFO - Recall: 0.7462
# INFO:__main__:Recall: 0.7462
# 2026-02-19 14:04:18 - __main__ - INFO - F1-Score: 0.8398
# INFO:__main__:F1-Score: 0.8398
# 2026-02-19 14:04:18 - __main__ - INFO - AUC: 0.9460
# INFO:__main__:AUC: 0.9460
# 2026-02-19 14:04:18 - __main__ - INFO - Misclassified: 111 (17.79%)
# INFO:__main__:Misclassified: 111 (17.79%)
# 2026-02-19 14:04:18 - __main__ - INFO - ==================================================
# INFO:__main__:==================================================
# 2026-02-19 14:04:18 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:04:18 - __main__ - INFO - EVALUATION COMPLETED SUCCESSFULLY
# INFO:__main__:EVALUATION COMPLETED SUCCESSFULLY
# 2026-02-19 14:04:18 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 14:04:18 - __main__ - INFO -
# ✅ Evaluation completed successfully!
# INFO:__main__:
# ✅ Evaluation completed successfully!
# 2026-02-19 14:04:18 - __main__ - INFO - 📊 Results saved to: reports/task1
# INFO:__main__:📊 Results saved to: reports/task1
# /content/Postdoctoral-Technical-Challenge
#
# ✅ Task 1 completed!

# %%
# @title 📊 Step 7: View Task 1 Results
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

print("="*60)
print("TASK 1 RESULTS")
print("="*60)

# Load metrics
results_file = Path('reports/task1/evaluation_results.json')
if results_file.exists():
    with open(results_file, 'r') as f:
        results = json.load(f)

    metrics = results.get('metrics', {})
    print("\n📊 Performance Metrics:")
    print(f"   Accuracy:  {metrics.get('accuracy', 0):.4f}")
    print(f"   Precision: {metrics.get('precision', 0):.4f}")
    print(f"   Recall:    {metrics.get('recall', 0):.4f}")
    print(f"   F1-Score:  {metrics.get('f1_score', 0):.4f}")
    print(f"   AUC:       {metrics.get('auc', 0):.4f}")

# Display figures
figures = {
    "Confusion Matrix": "reports/task1/figures/confusion_matrix.png",
    "ROC Curve": "reports/task1/figures/roc_curve.png",
    "Training Curves": "reports/task1/figures/training_curves.png",
    "Failure Cases": "reports/task1/figures/failure_cases.png"
}

for title, path in figures.items():
    if Path(path).exists():
        print(f"\n📈 {title}:")
        display(Image(filename=path))
# Out:
# ============================================================
# TASK 1 RESULTS
# ============================================================
#
# 📊 Performance Metrics:
#    Accuracy:  0.8510
#    Precision: 0.8249
#    Recall:    0.9667
#    F1-Score:  0.8902
#    AUC:       0.9223
#
# 📈 Confusion Matrix:
# 📈 ROC Curve:
# 📈 Training Curves:
# 📈 Failure Cases:

# %%
# @title 📝 Step 8: Run Task 2 - Medical Report Generation
print("="*60)
print("TASK 2: MEDICAL REPORT GENERATION")
print("="*60)

# Check if token is set
HF_TOKEN = userdata.get('HF_TOKEN')
if not HF_TOKEN:
    print("❌ HF_TOKEN not set! Please run Step 3 first.")
else:
    print(f"✅ HF_TOKEN is set: {HF_TOKEN[:5]}...{HF_TOKEN[-5:]}")

    # Option B: Run generate.py directly
    print("\n🔄 Running report generation")
    # %cd task2_report_generation

    # Generate reports (token will be picked up from environment)
    # !python generate_reports.py --token {HF_TOKEN}

    # %cd ..

    print("\n✅ Task 2 completed!")
# Out:
# ============================================================
# TASK 2: MEDICAL REPORT GENERATION
# ============================================================
# ✅ HF_TOKEN is set: hf_En...PYuyH
#
# 🔄 Running report generation
# /content/Postdoctoral-Technical-Challenge/task2_report_generation
# INFO:__main__:Initializing MedGemma-4b-it report generator...
# INFO:__main__:Using device: cuda
# INFO:__main__:Loading google/medgemma-4b-it...
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/processor_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/google/medgemma-4b-it/resolve/main/processor_config.json "HTTP/1.1 200 OK"
# processor_config.json: 100% 70.0/70.0 [00:00<00:00, 209kB/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google/medgemma-4b-it/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/processor_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/chat_template.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/chat_template.jinja "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/google/medgemma-4b-it/resolve/main/chat_template.jinja "HTTP/1.1 200 OK"
# chat_template.jinja: 100% 1.53k/1.53k [00:00<00:00, 5.29MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/audio_tokenizer_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google/medgemma-4b-it/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/processor_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/chat_template.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/chat_template.jinja "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/audio_tokenizer_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/processor_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/preprocessor_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/google/medgemma-4b-it/resolve/main/preprocessor_config.json "HTTP/1.1 200 OK"
# preprocessor_config.json: 100% 570/570 [00:00<00:00, 2.52MB/s]
# The image processor of type `Gemma3ImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/processor_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/preprocessor_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/google/medgemma-4b-it/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100% 1.16M/1.16M [00:00<00:00, 9.10MB/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google/medgemma-4b-it/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google/medgemma-4b-it/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/tokenizer.json "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google/medgemma-4b-it/xet-read-token/290cda5eeccbee130f987c4ad74a59ae6f196408 "HTTP/1.1 200 OK"
# tokenizer.json: 100% 33.4M/33.4M [00:00<00:00, 48.0MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/added_tokens.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/google/medgemma-4b-it/resolve/main/added_tokens.json "HTTP/1.1 200 OK"
# added_tokens.json: 100% 35.0/35.0 [00:00<00:00, 169kB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/special_tokens_map.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/google/medgemma-4b-it/resolve/main/special_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 100% 662/662 [00:00<00:00, 3.29MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/main/model.safetensors.index.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/google/medgemma-4b-it/resolve/main/model.safetensors.index.json "HTTP/1.1 200 OK"
# model.safetensors.index.json: 100% 90.6k/90.6k [00:00<00:00, 6.67MB/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google/medgemma-4b-it/revision/main "HTTP/1.1 200 OK"
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/290cda5eeccbee130f987c4ad74a59ae6f196408/model-00001-of-00002.safetensors "HTTP/1.1 302 Found"
# Downloading (incomplete total...):   0% 0.00/4.96G [00:00<?, ?B/s]INFO:httpx:HTTP Request: HEAD https://huggingface.co/google/medgemma-4b-it/resolve/290cda5eeccbee130f987c4ad74a59ae6f196408/model-00002-of-00002.safetensors "HTTP/1.1 302 Found"
# Downloading (incomplete total...): 100% 8.60G/8.60G [02:36<00:00, 54.5MB/s]
# Fetching 2 files: 100% 2/2 [02:36<00:00, 78.38s/it]
# Download complete: 100% 8.60G/8.60G [02:36<00:00, 54.8MB/s]
# Loading weights:  27% 239/883 [00:24<00:52, 12.24it/s, Materializing param=model.language_model.layers.18.mlp.up_proj.weight]^C
# /content/Postdoctoral-Technical-Challenge
#
# ✅ Task 2 completed!

# %%
# @title 📝 Step 9: View Task 2 Results

import json
from IPython.display import Image, display

print("="*60)
print("TASK 2 RESULTS")
print("="*60)

# Load quality analysis
qa_file = Path('task2_report_generation/reports/task2/generated_reports/quality_analysis.json')
if qa_file.exists():
    with open(qa_file, 'r') as f:
        analysis = json.load(f)

    print("\n📊 Prompt Performance:")
    print("-"*50)
    print(f"{'Prompt':20} {'Avg Words':12} {'Agreement':12}")
    print("-"*50)
    for prompt, stats in analysis.get('prompt_analysis', {}).items():
        print(f"{prompt:20} {stats.get('avg_word_count', 0):8.0f} words  {stats.get('agreement_with_truth', 0):8.1%}")

# Display sample reports
figures_dir = Path('task2_report_generation/reports/task2/figures')
if figures_dir.exists():
    report_images = sorted(figures_dir.glob('sample_*_report.png'))
    print(f"\n📸 Found {len(report_images)} report images")

    for img_path in report_images[:3]:  # Show first 3
        print(f"\n📄 {img_path.name}:")
        display(Image(filename=str(img_path)))
# Out:
# ============================================================
# TASK 2 RESULTS
# ============================================================
#
# 📊 Prompt Performance:
# --------------------------------------------------
# Prompt               Avg Words    Agreement
# --------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-496488904.py in <cell line: 0>()
#      19     print("-"*50)
#      20     for prompt, stats in analysis.get('prompt_analysis', {}).items():
# ---> 21         print(f"{prompt:20} {stats.get('avg_word_count', 0):8.0f} words  {stats.get('agreement_with_truth', 0):8.1%}")
#      22
#      23 # Display sample reports
#
# TypeError: unsupported format string passed to dict.__format__

# %%
# @title 🔍 Step 10: Run Task 3 - Build Retrieval Index

print("="*60)
print("TASK 3: BUILD RETRIEVAL INDEX")
print("="*60)

print("\n🔄 Building index directly")
# %cd task3_retrieval

# Build index
# !python build_index.py --model resnet18 --split test --index_type flat

# %cd ..

print("\n✅ Index built successfully!")
# Out:
# ============================================================
# TASK 3: BUILD RETRIEVAL INDEX
# ============================================================
#
# 🔄 Building index directly
# /content/Postdoctoral-Technical-Challenge/Postdoctoral-Technical-Challenge/Postdoctoral-Technical-Challenge/task3_retrieval
# 2026-02-19 13:31:45 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 13:31:45 - __main__ - INFO - BUILDING SEMANTIC RETRIEVAL INDEX
# INFO:__main__:BUILDING SEMANTIC RETRIEVAL INDEX
# 2026-02-19 13:31:45 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 13:31:45 - __main__ - INFO - Loading dataset...
# INFO:__main__:Loading dataset...
# INFO:data.data_loader:Training set size: 4708
# INFO:data.data_loader:Validation set size: 524
# INFO:data.data_loader:Test set size: 624
# 2026-02-19 13:31:45 - __main__ - INFO - Using test set with 624 images
# INFO:__main__:Using test set with 624 images
# 2026-02-19 13:31:45 - __main__ - INFO - Initializing embedding extractor with resnet18
# INFO:__main__:Initializing embedding extractor with resnet18
# 2026-02-19 13:31:45 - __main__ - INFO - Loaded resnet18 model with embedding dim 512
# INFO:__main__:Loaded resnet18 model with embedding dim 512
# 2026-02-19 13:31:45 - __main__ - INFO - Extracting embeddings...
# INFO:__main__:Extracting embeddings...
# Extracting embeddings: 100% 10/10 [00:01<00:00,  6.29it/s]
# 2026-02-19 13:31:47 - __main__ - INFO - Extracted 624 embeddings of dimension 512
# INFO:__main__:Extracted 624 embeddings of dimension 512
# 2026-02-19 13:31:47 - __main__ - INFO - Building index with 624 samples
# INFO:__main__:Building index with 624 samples
# 2026-02-19 13:31:47 - __main__ - INFO - Created flat index with 512 dimensions
# INFO:__main__:Created flat index with 512 dimensions
# 2026-02-19 13:31:47 - __main__ - INFO - Index built successfully. Total vectors: 624
# INFO:__main__:Index built successfully. Total vectors: 624
# 2026-02-19 13:31:47 - __main__ - INFO - Class distribution: {'normal': 234, 'pneumonia': 390}
# INFO:__main__:Class distribution: {'normal': 234, 'pneumonia': 390}
# 2026-02-19 13:31:47 - __main__ - INFO - FAISS index saved to models/embeddings/pneumonia_retrieval.faiss
# INFO:__main__:FAISS index saved to models/embeddings/pneumonia_retrieval.faiss
# 2026-02-19 13:31:47 - __main__ - INFO - Metadata saved to models/embeddings/pneumonia_retrieval_metadata.pkl
# INFO:__main__:Metadata saved to models/embeddings/pneumonia_retrieval_metadata.pkl
# 2026-02-19 13:31:47 - __main__ - INFO - All files saved to models/embeddings
# INFO:__main__:All files saved to models/embeddings
#
# ============================================================
# INDEX BUILDING COMPLETE
# ============================================================
# Time taken: 1.97s
# Number of vectors: 624
# Embedding dimension: 512
# Index type: flat
# Class distribution: {'normal': 234, 'pneumonia': 390}
#
# Files saved to: models/embeddings
#   - pneumonia_retrieval.faiss (FAISS index)
#   - pneumonia_retrieval_metadata.pkl (metadata)
#   - pneumonia_retrieval_metadata.json (metadata JSON)
#   - pneumonia_retrieval_id_map.json (ID to index mapping)
#   - index_stats.json (statistics)
# /content/Postdoctoral-Technical-Challenge/Postdoctoral-Technical-Challenge/Postdoctoral-Technical-Challenge
#
# ✅ Index built successfully!

# %%
# @title 🔎 Step 11: Run Task 3 - Image Search

print("="*60)
print("TASK 3: IMAGE SEARCH")
print("="*60)

# %cd task3_retrieval

# Choose search mode
print("\n📋 Select search mode:")
print("   1. Demo (both image and text)")
print("   2. Image-to-image search")
print("   3. Text-to-image search")
print("   4. Evaluation")

mode = input("\nEnter choice (1-4): ").strip()

if mode == '1':
    # !python search.py --mode demo --save_results
elif mode == '2':
    # !python search.py --mode image --k 5 --save_results
elif mode == '3':
    query = input("Enter text query (default: pneumonia): ").strip() or "pneumonia"
    # !python search.py --mode text --query "{query}" --k 5 --save_results
elif mode == '4':
    # !python search.py --mode eval --num_queries 50
else:
    print("❌ Invalid choice")

# %cd ..

print("\n✅ Search completed!")
# Out:
# ============================================================
# TASK 3: IMAGE SEARCH
# ============================================================
# /content/Postdoctoral-Technical-Challenge/Postdoctoral-Technical-Challenge/Postdoctoral-Technical-Challenge/task3_retrieval
#
# 📋 Select search mode:
#    1. Demo (both image and text)
#    2. Image-to-image search
#    3. Text-to-image search
#    4. Evaluation
#
# Enter choice (1-4): 1
# 2026-02-19 13:32:02 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 13:32:02 - __main__ - INFO - IMAGE RETRIEVAL SYSTEM
# INFO:__main__:IMAGE RETRIEVAL SYSTEM
# 2026-02-19 13:32:02 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2026-02-19 13:32:02 - __main__ - INFO - Initializing retrieval system with config: RetrievalConfig(index_name='pneumonia_retrieval', index_dir=PosixPath('models/embeddings'), model_name='resnet18', embedding_dim=512, default_k=5, similarity_threshold=0.5, output_dir=PosixPath('reports/task3'), figures_dir=PosixPath('reports/task3/figures'), device='cpu')
# INFO:__main__:Initializing retrieval system with config: RetrievalConfig(index_name='pneumonia_retrieval', index_dir=PosixPath('models/embeddings'), model_name='resnet18', embedding_dim=512, default_k=5, similarity_threshold=0.5, output_dir=PosixPath('reports/task3'), figures_dir=PosixPath('reports/task3/figures'), device='cpu')
# 2026-02-19 13:32:02 - __main__ - INFO - Loaded FAISS index with 624 vectors
# INFO:__main__:Loaded FAISS index with 624 vectors
# 2026-02-19 13:32:02 - __main__ - INFO - Index stats: {'num_vectors': 624, 'embedding_dim': 512, 'index_type': 'flat', 'similarity_metric': 'cosine', 'class_distribution': {'normal': 234, 'pneumonia': 390}, 'normalized': True, 'build_time': '2026-02-19T13:31:47.041213', 'image_id_format': 'test_{batch_idx:04d}_{sample_idx:03d}'}
# INFO:__main__:Index stats: {'num_vectors': 624, 'embedding_dim': 512, 'index_type': 'flat', 'similarity_metric': 'cosine', 'class_distribution': {'normal': 234, 'pneumonia': 390}, 'normalized': True, 'build_time': '2026-02-19T13:31:47.041213', 'image_id_format': 'test_{batch_idx:04d}_{sample_idx:03d}'}
# 2026-02-19 13:32:03 - __main__ - INFO - Created mappings: 624 entries, 234 normal, 390 pneumonia
# INFO:__main__:Created mappings: 624 entries, 234 normal, 390 pneumonia
# INFO:data.data_loader:Training set size: 4708
# INFO:data.data_loader:Validation set size: 524
# INFO:data.data_loader:Test set size: 624
# 2026-02-19 13:32:03 - __main__ - INFO - Dataset loaded: 624 test samples
# INFO:__main__:Dataset loaded: 624 test samples
# 2026-02-19 13:32:03 - task3_retrieval.build_index - INFO - Initializing embedding extractor with resnet18
# INFO:task3_retrieval.build_index:Initializing embedding extractor with resnet18
# 2026-02-19 13:32:03 - task3_retrieval.build_index - INFO - Loaded resnet18 model with embedding dim 512
# INFO:task3_retrieval.build_index:Loaded resnet18 model with embedding dim 512
# 2026-02-19 13:32:03 - __main__ - INFO - Built image map with 624 images
# INFO:__main__:Built image map with 624 images
# 2026-02-19 13:32:03 - __main__ - INFO - Sample image IDs: ['test_0000_000', 'test_0000_001', 'test_0000_002', 'test_0000_003', 'test_0000_004']
# INFO:__main__:Sample image IDs: ['test_0000_000', 'test_0000_001', 'test_0000_002', 'test_0000_003', 'test_0000_004']
# 2026-02-19 13:32:03 - __main__ - INFO - Retrieval system initialization complete
# INFO:__main__:Retrieval system initialization complete
#
# ==================================================
# RETRIEVAL SYSTEM DEMO
# ==================================================
#
# 1. Image-to-Image Search
#    Query: Pneumonia
# 2026-02-19 13:32:03 - __main__ - INFO - Loaded 3/3 result images
# INFO:__main__:Loaded 3/3 result images
#
# 2. Text-to-Image Search
#    Query: 'pneumonia'
# 2026-02-19 13:32:04 - __main__ - INFO - Text query mapped to pneumonia (label=1)
# INFO:__main__:Text query mapped to pneumonia (label=1)
# 2026-02-19 13:32:04 - __main__ - INFO - Loaded 3/3 result images
# INFO:__main__:Loaded 3/3 result images
# 2026-02-19 13:32:04 - __main__ - INFO - Text search completed in 0.001s, found 3 results
# INFO:__main__:Text search completed in 0.001s, found 3 results
#    Query: 'normal chest'
# 2026-02-19 13:32:04 - __main__ - INFO - Text query mapped to normal (label=0)
# INFO:__main__:Text query mapped to normal (label=0)
# 2026-02-19 13:32:04 - __main__ - INFO - Loaded 3/3 result images
# INFO:__main__:Loaded 3/3 result images
# 2026-02-19 13:32:04 - __main__ - INFO - Text search completed in 0.001s, found 3 results
# INFO:__main__:Text search completed in 0.001s, found 3 results
#
# ✅ Demo completed. Check the figures directory for results.
# 2026-02-19 13:32:05 - __main__ - INFO - Search history saved to reports/task3/search_history.json
# INFO:__main__:Search history saved to reports/task3/search_history.json
#
# ✅ Task 3 completed successfully!
# 📊 Results saved to: reports/task3
# /content/Postdoctoral-Technical-Challenge/Postdoctoral-Technical-Challenge/Postdoctoral-Technical-Challenge
#
# ✅ Search completed!

# %%
# @title 🔍 Step 12: View Task 3 Results

import json
from IPython.display import Image, display

print("="*60)
print("TASK 3 RESULTS")
print("="*60)

# Load evaluation results
eval_file = Path('reports/task3/retrieval_evaluation.json')
if eval_file.exists():
    with open(eval_file, 'r') as f:
        results = json.load(f)

    print("\n📊 Retrieval Performance:")
    precisions = results.get('precision_at_k', {})
    for k, v in precisions.items():
        print(f"   {k}: {v:.4f}")
    print(f"   mAP: {results.get('mean_average_precision', 0):.4f}")

# Display search results
figures_dir = Path('reports/task3/figures')
if figures_dir.exists():
    search_images = sorted(figures_dir.glob('*_search_*.png'))
    print(f"\n📸 Found {len(search_images)} search result images")

    for img_path in search_images[:4]:  # Show first 4
        print(f"\n📊 {img_path.name}:")
        display(Image(filename=str(img_path)))
# Out:
# ============================================================
# TASK 3 RESULTS
# ============================================================
#
# 📸 Found 2 search result images
#
# 📊 image_search_20260217_151326.png:
# 📊 text_search_20260217_151326.png:

# %% [markdown]
# ## Run All Tasks At Once

# %%
# @title 🚀 Step 13: Run All Tasks (Complete Pipeline)

import time

print("="*60)
print("RUNNING COMPLETE PIPELINE")
print("="*60)

# Check token for Task 2
if not userdata.get('HF_TOKEN'):
    print("⚠️  HF_TOKEN not set! Task 2 may fail.")
    proceed = input("Continue anyway? (y/n): ").lower()
    if proceed != 'y':
        print("❌ Aborted. Please set token in Step 3 first.")
    else:
        print("⚠️  Continuing without token...")
else:
    print("✅ HF_TOKEN is set")

start_time = time.time()

# Task 1
print("\n" + "🔥"*30)
print("TASK 1: CLASSIFICATION")
print("🔥"*30)
# %cd task1_classification
# !python train.py --model resnet18 --epochs 1 --batch_size 32
# !python evaluate.py --model_path models/saved/best_model_resnet18.pth
# %cd ..

# Task 2
print("\n" + "🔥"*30)
print("TASK 2: REPORT GENERATION")
print("🔥"*30)
# %cd task2_report_generation
# !python generate.py --samples 2 --max_tokens 200
# %cd ..

# Task 3
print("\n" + "🔥"*30)
print("TASK 3: RETRIEVAL SYSTEM")
print("🔥"*30)
# %cd task3_retrieval
# !python build_index.py --model resnet18
# !python search.py --mode demo
# %cd ..

elapsed = time.time() - start_time
print("\n" + "="*60)
print(f"✅ ALL TASKS COMPLETED in {elapsed/60:.2f} minutes!")
print("="*60)
# Out:
# ============================================================
# RUNNING COMPLETE PIPELINE
# ============================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2632995851.py in <cell line: 0>()
#       8
#       9 # Check token for Task 2
# ---> 10 if not userdata.get('HF_TOKEN'):
#      11     print("⚠️  HF_TOKEN not set! Task 2 may fail.")
#      12     proceed = input("Continue anyway? (y/n): ").lower()
#
# NameError: name 'userdata' is not defined

# %%
# @title 💾 Step 14: Save Results to Google Drive

print("="*60)
print("SAVING RESULTS TO GOOGLE DRIVE")
print("="*60)

# Check if Drive is mounted
if not os.path.exists('/content/drive'):
    print("❌ Google Drive not mounted. Please run Step 4 first.")
else:
    # Create backup folder
    # !mkdir -p /content/drive/MyDrive/pneumonia_ai_results

    # Copy all results
    # !cp -r reports/ /content/drive/MyDrive/pneumonia_ai_results/
    # !cp -r models/saved/ /content/drive/MyDrive/pneumonia_ai_results/models/
    # !cp -r models/embeddings/ /content/drive/MyDrive/pneumonia_ai_results/embeddings/

    print("\n✅ Results saved to Google Drive:")
    # !ls -la /content/drive/MyDrive/pneumonia_ai_results/
# Out:
# ============================================================
# SAVING RESULTS TO GOOGLE DRIVE
# ============================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3031511437.py in <cell line: 0>()
#       6
#       7 # Check if Drive is mounted
# ----> 8 if not os.path.exists('/content/drive'):
#       9     print("❌ Google Drive not mounted. Please run Step 4 first.")
#      10 else:
#
# NameError: name 'os' is not defined

# %%
# @title 📥 Step 15: Download Results

from google.colab import files
import zipfile

print("="*60)
print("DOWNLOAD RESULTS")
print("="*60)

# Create zip archives
# !zip -r reports.zip reports/
# !zip -r models.zip models/saved/ models/embeddings/

print("\n📁 Available files:")
# !ls -lh *.zip

# Download options
print("\nSelect files to download:")
download_reports = input("Download reports.zip? (y/n): ").lower() == 'y'
download_models = input("Download models.zip? (y/n): ").lower() == 'y'

if download_reports:
    print("\n📥 Downloading reports.zip...")
    files.download('reports.zip')

if download_models:
    print("\n📥 Downloading models.zip...")
    files.download('models.zip')

print("\n✅ Download complete!")

# %%
# @title 🧹 Step 16: Clean Up (Optional)

print("="*60)
print("CLEAN UP")
print("="*60)

confirm = input("This will delete all generated files. Continue? (y/n): ").lower()
if confirm == 'y':
    # !rm -rf reports/
    # !rm -rf models/saved/
    # !rm -rf models/embeddings/
    # !rm -rf task1_classification/__pycache__/
    # !rm -rf task2_report_generation/__pycache__/
    # !rm -rf task3_retrieval/__pycache__/
    # !rm -rf utils/__pycache__/
    # !rm -rf data/__pycache__/
    # !rm -f *.zip
    # !rm -f .env  # Remove token file (optional)
    print("\n✅ Clean up complete!")
    print("⚠️  Note: .env file with token was also removed")
else:
    print("\n✅ Clean up skipped.")
